# %%
import sys

sys.path.append('/home/martin/proyectos/proyectovc/.venv/lib/python3.12/site-packages')

import cv2
import numpy as np
import pytesseract
import skimage

print("osk")
# Out:
# ok

# %%
print("hola")
# Out:
# hola
